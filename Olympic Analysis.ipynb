# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('default')

df = pd.read_csv('https://raw.githubusercontent.com/AshishJangra27/Skill-India-AI-ML-Scholarship/main/Summer%20Olympics/summer.csv')

df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %% [markdown]
# 1. In how many cities Summer Olympics is held so far?

# %%
print("No of Cities:", len(df['City'].unique()))
# Out:
# No of Cities: 22

# %% [markdown]
# 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
g_df = df[df['Medal'] == 'Gold']
data = [[sport, len(g_df[g_df['Sport'] == sport])] for sport in g_df['Sport'].unique()]

data = pd.DataFrame(data, columns=['Sport', 'Medal'])
data.sort_values(by = 'Medal', ascending = False, inplace = True)

plt.figure(figsize = (15,8))
barplot = plt.bar(data['Sport'][:5], data['Medal'][:5], color = 'royalblue', alpha = .7)

for bar in barplot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')

plt.title('Top Sports with Most Gold Medals')
plt.ylabel('No of Gold Medals')
plt.xlabel('Sport')
# Out:
# Text(0.5, 0, 'Sport')

# %% [markdown]
# 3. Which sport is having most number of medals so far? (Top 5)

# %%
data = [[sport, len(df[df['Sport'] == sport])] for sport in df['Sport'].unique()]
data = pd.DataFrame(data, columns=['Sport', 'Medal'])
data.sort_values(by = 'Medal', ascending = False, inplace = True)

plt.figure(figsize = (15,8))
barplot = plt.bar(data['Sport'][:5], data['Medal'][:5], color = 'limegreen', alpha = .7)

for bar in barplot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')

plt.title('Top Sports with Most Medals')
plt.ylabel('No of Medals')
plt.xlabel('Sport')
# Out:
# Text(0.5, 0, 'Sport')

# %% [markdown]
# 4. Which player has won most number of medals? (Top 5)

# %%
data = [[Athlete, len(df[df['Athlete'] == Athlete])] for Athlete in df['Athlete'].unique()]
data = pd.DataFrame(data, columns=['Athlete', 'Medal'])
data.sort_values(by = 'Medal', ascending = False, inplace = True)

plt.figure(figsize = (15,8))
barplot = plt.bar(data['Athlete'][:5], data['Medal'][:5], color = 'lightpink', alpha = .7)

for bar in barplot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')

plt.title('Athlete with Most Medals')
plt.ylabel('No of Medals')
plt.xlabel('Athlete Name')
# Out:
# Text(0.5, 0, 'Athlete Name')

# %% [markdown]
# 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
g_df = df[df['Medal'] == 'Gold']
data = [[Athlete, len(g_df[g_df['Athlete'] == Athlete])] for Athlete in g_df['Athlete'].unique()]
data = pd.DataFrame(data, columns=['Athlete', 'Medal'])
data.sort_values(by = 'Medal', ascending = False, inplace = True)

plt.figure(figsize = (15,8))
barplot = plt.bar(data['Athlete'][:5], data['Medal'][:5], color = 'orange', alpha = .7)

for bar in barplot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')

plt.title('Athlete with Most Medals')
plt.ylabel('No of Gold Medals')
plt.xlabel('Athlete Name')
# Out:
# Text(0.5, 0, 'Athlete Name')

# %% [markdown]
# 6. In which year India won first Gold Medal in Summer Olympics?

# %%
ind_df = df[df['Country'] == 'IND'].sort_values(by= 'Year')
print("India won First Gold Medal in :", int((ind_df[ind_df['Medal'] == 'Gold'])['Year'][0:1]))
# Out:
# India won First Gold Medal in : 1928

# %% [markdown]
# 7. Which event is most popular in terms on number of players? (Top 5)

# %%
data = [[Event, len(df[df['Event'] == Event])] for Event in df['Event'].unique()]
data = pd.DataFrame(data, columns=['Event', 'No of Participation'])
data.sort_values(by = 'No of Participation', ascending = False, inplace = True)

plt.figure(figsize = (15,8))
barplot = plt.bar(data['Event'][:5], data['No of Participation'][:5], color = '#30D5C8', alpha = .7)

for bar in barplot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')

plt.title('Most popular events')
plt.ylabel('No of Participation')
plt.xlabel('Event Name')
# Out:
# Text(0.5, 0, 'Event Name')

# %% [markdown]
# 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
f_df = df[df['Gender'] == 'Women']
g_df = f_df[f_df['Medal'] == 'Gold']
data = [[Sport, len(g_df[g_df['Sport'] == Sport])] for Sport in g_df['Sport'].unique()]
data = pd.DataFrame(data, columns=['Sport', 'No of Female players'])
data.sort_values(by = 'No of Female players', ascending = False, inplace = True)

plt.figure(figsize = (15,8))
barplot = plt.bar(data['Sport'][:5], data['No of Female players'][:5], color = '#a83cf0', alpha = .7)

for bar in barplot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')

plt.title('Sport having most female Gold Medalists')
plt.ylabel('No of Female players')
plt.xlabel('Sport Name')
# Out:
# Text(0.5, 0, 'Sport Name')
